# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
import datetime

# %%
allsec=pd.read_csv(r'C:\Users\bshiv\Downloads\Python-for-Finance-Repo-master\01-Python-Crash-Course\ALLSEC.BO.csv')
print(allsec)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-08-14  270.450012  270.500000  270.350006  270.500000  270.500000
# 1    2019-08-16  290.000000  290.000000  275.100006  281.000000  281.000000
# 2    2019-08-19  271.000000  271.000000  271.000000  271.000000  271.000000
# 3    2019-08-20  268.149994  280.000000  268.149994  274.000000  274.000000
# 4    2019-08-21  262.049988  265.549988  262.049988  265.399994  265.399994
# ..          ...         ...         ...         ...         ...         ...
# 242  2020-08-10  216.000000  250.000000  215.050003  231.899994  231.899994
# 243  2020-08-11  250.000000  278.250000  240.000000  278.250000  278.250000
# 244  2020-08-12  277.350006  301.399994  277.350006  283.200012  283.200012
# 245  2020-08-13  272.850006  310.000000  255.149994  286.100006  286.100006
# 246  2020-08-14  293.799988  293.799988  274.000000  279.850006  279.850006
#
#       Volume
# 0       75.0
# 1       13.0
# ...

# %%
allsec_close=allsec.drop(['Open','High','Low','Volume','Close'],axis=1)
print(allsec_close)
allsec_close.info()
allsec_close['Date']=pd.to_datetime(allsec_close['Date'])
allsec_close.info()
allsec_close.set_index('Date',inplace=True)
allsec_close
# Out:
#            Date   Adj Close
# 0    2019-08-14  270.500000
# 1    2019-08-16  281.000000
# 2    2019-08-19  271.000000
# 3    2019-08-20  274.000000
# 4    2019-08-21  265.399994
# ..          ...         ...
# 242  2020-08-10  231.899994
# 243  2020-08-11  278.250000
# 244  2020-08-12  283.200012
# 245  2020-08-13  286.100006
# 246  2020-08-14  279.850006
#
# [247 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       247 non-null    object
#  1   Adj Close  246 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       247 non-null    datetime64[ns]
#  1   Adj Close  246 non-null    float64
# ...

# %%
bhansali=pd.read_csv(r'C:\Users\bshiv\Downloads\Python-for-Finance-Repo-master\01-Python-Crash-Course\BEPL.BO.csv')
bhansali_close=bhansali.drop(['Open','High','Low','Volume','Close'],axis=1)
print(bhansali_close)
bhansali_close['Date']=pd.to_datetime(bhansali_close['Date'])
bhansali_close.info()
bhansali_close.set_index('Date',inplace=True)
bhansali_close
# Out:
#            Date  Adj Close
# 0    2019-08-14  57.234680
# 1    2019-08-16  58.772179
# 2    2019-08-19  58.226616
# 3    2019-08-20  57.284275
# 4    2019-08-21  54.655643
# ..          ...        ...
# 242  2020-08-10  45.299999
# 243  2020-08-11  45.799999
# 244  2020-08-12  45.599998
# 245  2020-08-13  45.700001
# 246  2020-08-14  46.549999
#
# [247 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       247 non-null    datetime64[ns]
#  1   Adj Close  246 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.0 KB
#             Adj Close
# Date
# 2019-08-14  57.234680
# 2019-08-16  58.772179
# 2019-08-19  58.226616
# 2019-08-20  57.284275
# 2019-08-21  54.655643
# ...               ...
# 2020-08-10  45.299999
# 2020-08-11  45.799999
# 2020-08-12  45.599998
# 2020-08-13  45.700001
# ...

# %%
eclerx=pd.read_csv(r'C:\Users\bshiv\Downloads\Python-for-Finance-Repo-master\01-Python-Crash-Course\ECLERX.BO.csv')
eclerx_close=eclerx.drop(['Open','High','Low','Volume','Close'],axis=1)
print(eclerx_close)
eclerx_close['Date']=pd.to_datetime(eclerx_close['Date'])
eclerx_close.set_index('Date',inplace=True)
eclerx_close
# Out:
#            Date   Adj Close
# 0    2019-08-16  489.904358
# 1    2019-08-19  497.921692
# 2    2019-08-20  498.618835
# 3    2019-08-21  483.549988
# 4    2019-08-22  471.950012
# ..          ...         ...
# 241  2020-08-10  488.049988
# 242  2020-08-11  512.450012
# 243  2020-08-12  517.099976
# 244  2020-08-13  620.500000
# 245  2020-08-14  675.599976
#
# [246 rows x 2 columns]
#              Adj Close
# Date
# 2019-08-16  489.904358
# 2019-08-19  497.921692
# 2019-08-20  498.618835
# 2019-08-21  483.549988
# 2019-08-22  471.950012
# ...                ...
# 2020-08-10  488.049988
# 2020-08-11  512.450012
# 2020-08-12  517.099976
# 2020-08-13  620.500000
# 2020-08-14  675.599976
#
# [246 rows x 1 columns]

# %%
sharda=pd.read_csv(r'C:\Users\bshiv\Downloads\Python-for-Finance-Repo-master\01-Python-Crash-Course\SHARDA.BO.csv')
sharda_close=sharda.drop(['Open','High','Low','Volume','Close'],axis=1)
print(sharda_close)
sharda_close['Date']=pd.to_datetime(sharda_close['Date'])
sharda_close.set_index('Date',inplace=True)
sharda_close
# Out:
#            Date   Adj Close
# 0    2019-08-16  963.000000
# 1    2019-08-19  983.400024
# 2    2019-08-20  934.049988
# 3    2019-08-21  935.000000
# 4    2019-08-22  919.150024
# ..          ...         ...
# 241  2020-08-10  857.349976
# 242  2020-08-11  882.299988
# 243  2020-08-12  882.000000
# 244  2020-08-13  921.500000
# 245  2020-08-14  979.400024
#
# [246 rows x 2 columns]
#              Adj Close
# Date
# 2019-08-16  963.000000
# 2019-08-19  983.400024
# 2019-08-20  934.049988
# 2019-08-21  935.000000
# 2019-08-22  919.150024
# ...                ...
# 2020-08-10  857.349976
# 2020-08-11  882.299988
# 2020-08-12  882.000000
# 2020-08-13  921.500000
# 2020-08-14  979.400024
#
# [246 rows x 1 columns]

# %%
maithan=pd.read_csv(r'C:\Users\bshiv\Downloads\Python-for-Finance-Repo-master\01-Python-Crash-Course\MAITHANALL.BO.csv')
maithan_close=maithan.drop(['Open','High','Low','Volume','Close'],axis=1)
print(maithan_close)
maithan_close['Date']=pd.to_datetime(maithan_close['Date'])
maithan_close.set_index('Date',inplace=True)
maithan_close
# Out:
#            Date   Adj Close
# 0    2019-08-14  432.806946
# 1    2019-08-16  428.117554
# 2    2019-08-19  435.521881
# 3    2019-08-20  426.093719
# 4    2019-08-21  421.404327
# ..          ...         ...
# 242  2020-08-10  530.450012
# 243  2020-08-11  506.750000
# 244  2020-08-12  514.599976
# 245  2020-08-13  505.500000
# 246  2020-08-14  494.950012
#
# [247 rows x 2 columns]
#              Adj Close
# Date
# 2019-08-14  432.806946
# 2019-08-16  428.117554
# 2019-08-19  435.521881
# 2019-08-20  426.093719
# 2019-08-21  421.404327
# ...                ...
# 2020-08-10  530.450012
# 2020-08-11  506.750000
# 2020-08-12  514.599976
# 2020-08-13  505.500000
# 2020-08-14  494.950012
#
# [247 rows x 1 columns]

# %%
meera=pd.read_csv(r'C:\Users\bshiv\Downloads\Python-for-Finance-Repo-master\01-Python-Crash-Course\MEERA.BO.csv')
meera_close=meera.drop(['Open','High','Low','Volume','Close'],axis=1)
print(meera_close)
meera_close['Date']=pd.to_datetime(meera_close['Date'])
meera_close.set_index('Date',inplace=True)
meera_close
# Out:
#            Date  Adj Close
# 0    2019-08-16  77.430405
# 1    2019-08-19  77.430405
# 2    2019-08-20  75.596527
# 3    2019-08-21  75.596527
# 4    2019-08-22  73.375427
# ..          ...        ...
# 240  2020-08-07  42.000000
# 241  2020-08-10  42.200001
# 242  2020-08-11  39.549999
# 243  2020-08-12  41.849998
# 244  2020-08-13  39.150002
#
# [245 rows x 2 columns]
#             Adj Close
# Date
# 2019-08-16  77.430405
# 2019-08-19  77.430405
# 2019-08-20  75.596527
# 2019-08-21  75.596527
# 2019-08-22  73.375427
# ...               ...
# 2020-08-07  42.000000
# 2020-08-10  42.200001
# 2020-08-11  39.549999
# 2020-08-12  41.849998
# 2020-08-13  39.150002
#
# [245 rows x 1 columns]

# %%
snl=pd.read_csv(r'C:\Users\bshiv\Downloads\Python-for-Finance-Repo-master\01-Python-Crash-Course\SNL.BO.csv')
snl_close=snl.drop(['Open','High','Low','Volume','Close'],axis=1)
print(snl_close)
snl_close['Date']=pd.to_datetime(snl_close['Date'])
snl_close.set_index('Date',inplace=True)
snl_close
# Out:
#            Date   Adj Close
# 0    2019-08-16  195.199997
# 1    2019-08-19  195.199997
# 2    2019-08-20  195.199997
# 3    2019-08-21  189.832001
# 4    2019-08-22  190.271194
# ..          ...         ...
# 241  2020-08-10  106.150002
# 242  2020-08-11  106.000000
# 243  2020-08-12  107.000000
# 244  2020-08-13  107.000000
# 245  2020-08-14  106.000000
#
# [246 rows x 2 columns]
#              Adj Close
# Date
# 2019-08-16  195.199997
# 2019-08-19  195.199997
# 2019-08-20  195.199997
# 2019-08-21  189.832001
# 2019-08-22  190.271194
# ...                ...
# 2020-08-10  106.150002
# 2020-08-11  106.000000
# 2020-08-12  107.000000
# 2020-08-13  107.000000
# 2020-08-14  106.000000
#
# [246 rows x 1 columns]

# %%
amaze=pd.read_csv(r'C:\Users\bshiv\Downloads\Python-for-Finance-Repo-master\01-Python-Crash-Course\AMAZEENT.BO.csv')
amaze_close=amaze.drop(['Open','High','Low','Volume','Close'],axis=1)
print(amaze_close)
amaze_close['Date']=pd.to_datetime(amaze_close['Date'])
amaze_close.set_index('Date',inplace=True)
amaze_close
# Out:
#            Date  Adj Close
# 0    2019-08-16  39.799999
# 1    2019-08-19  39.799999
# 2    2019-08-20  39.799999
# 3    2019-08-21  39.799999
# 4    2019-08-22  39.799999
# ..          ...        ...
# 241  2020-08-10  46.549999
# 242  2020-08-11  51.250000
# 243  2020-08-12  53.799999
# 244  2020-08-13  56.450001
# 245  2020-08-14  59.250000
#
# [246 rows x 2 columns]
#             Adj Close
# Date
# 2019-08-16  39.799999
# 2019-08-19  39.799999
# 2019-08-20  39.799999
# 2019-08-21  39.799999
# 2019-08-22  39.799999
# ...               ...
# 2020-08-10  46.549999
# 2020-08-11  51.250000
# 2020-08-12  53.799999
# 2020-08-13  56.450001
# 2020-08-14  59.250000
#
# [246 rows x 1 columns]

# %%
caplin=pd.read_csv(r'C:\Users\bshiv\Downloads\Python-for-Finance-Repo-master\01-Python-Crash-Course\CAPPL.BO.csv')
caplin_close=caplin.drop(['Open','High','Low','Volume','Close'],axis=1)
print(caplin_close)
caplin_close['Date']=pd.to_datetime(caplin_close['Date'])
caplin_close.set_index('Date',inplace=True)
caplin_close
# Out:
#            Date   Adj Close
# 0    2019-08-16  440.590179
# 1    2019-08-19  426.012543
# 2    2019-08-20  416.623566
# 3    2019-08-21  399.377502
# 4    2019-08-22  398.389191
# ..          ...         ...
# 241  2020-08-10  570.500000
# 242  2020-08-11  536.150024
# 243  2020-08-12  510.350006
# 244  2020-08-13  556.799988
# 245  2020-08-14  547.000000
#
# [246 rows x 2 columns]
#              Adj Close
# Date
# 2019-08-16  440.590179
# 2019-08-19  426.012543
# 2019-08-20  416.623566
# 2019-08-21  399.377502
# 2019-08-22  398.389191
# ...                ...
# 2020-08-10  570.500000
# 2020-08-11  536.150024
# 2020-08-12  510.350006
# 2020-08-13  556.799988
# 2020-08-14  547.000000
#
# [246 rows x 1 columns]

# %%
balmer=pd.read_csv(r'C:\Users\bshiv\Downloads\Python-for-Finance-Repo-master\01-Python-Crash-Course\BLIL.BO.csv')
balmer_close=balmer.drop(['Open','High','Low','Volume','Close'],axis=1)
print(balmer_close)
balmer_close['Date']=pd.to_datetime(balmer_close['Date'])
balmer_close.set_index('Date',inplace=True)
balmer_close
# Out:
#            Date   Adj Close
# 0    2019-08-16  361.550293
# 1    2019-08-19  364.956787
# 2    2019-08-20  364.157745
# 3    2019-08-21  362.181152
# 4    2019-08-22  356.209259
# ..          ...         ...
# 241  2020-08-10  402.850006
# 242  2020-08-11  402.200012
# 243  2020-08-12  399.149994
# 244  2020-08-13  402.850006
# 245  2020-08-14  400.350006
#
# [246 rows x 2 columns]
#              Adj Close
# Date
# 2019-08-16  361.550293
# 2019-08-19  364.956787
# 2019-08-20  364.157745
# 2019-08-21  362.181152
# 2019-08-22  356.209259
# ...                ...
# 2020-08-10  402.850006
# 2020-08-11  402.200012
# 2020-08-12  399.149994
# 2020-08-13  402.850006
# 2020-08-14  400.350006
#
# [246 rows x 1 columns]

# %%
stocks=pd.concat([allsec_close,bhansali_close,eclerx_close,sharda_close,maithan_close,meera_close,snl_close,amaze_close,caplin_close,balmer_close],axis=1)
stocks.columns=['Allsec','Bhansali','Eclerx','Sharda','Maithan','Meera','SNL','Amaze','Caplin','Balmer']
stocks.head()
# Out:
#                 Allsec   Bhansali      Eclerx      Sharda     Maithan  \
# Date
# 2019-08-14  270.500000  57.234680         NaN         NaN  432.806946
# 2019-08-16  281.000000  58.772179  489.904358  963.000000  428.117554
# 2019-08-19  271.000000  58.226616  497.921692  983.400024  435.521881
# 2019-08-20  274.000000  57.284275  498.618835  934.049988  426.093719
# 2019-08-21  265.399994  54.655643  483.549988  935.000000  421.404327
#
#                 Meera         SNL      Amaze      Caplin      Balmer
# Date
# 2019-08-14        NaN         NaN        NaN         NaN         NaN
# 2019-08-16  77.430405  195.199997  39.799999  440.590179  361.550293
# 2019-08-19  77.430405  195.199997  39.799999  426.012543  364.956787
# 2019-08-20  75.596527  195.199997  39.799999  416.623566  364.157745
# 2019-08-21  75.596527  189.832001  39.799999  399.377502  362.181152

# %%
stocks.pct_change(1).mean()
# Out:
# Allsec      0.000763
# Bhansali    0.000045
# Eclerx      0.002031
# Sharda      0.001000
# Maithan     0.001174
# Meera      -0.001847
# SNL        -0.001426
# Amaze       0.001833
# Caplin      0.001769
# Balmer      0.000627
# dtype: float64

# %%
stocks.pct_change(1).corr()
# Out:
#             Allsec  Bhansali    Eclerx    Sharda   Maithan     Meera  \
# Allsec    1.000000  0.205747  0.234677  0.217806  0.239237  0.191219
# Bhansali  0.205747  1.000000  0.162492  0.197875  0.262795  0.148113
# Eclerx    0.234677  0.162492  1.000000  0.232817  0.250292  0.005760
# Sharda    0.217806  0.197875  0.232817  1.000000  0.376635  0.179494
# Maithan   0.239237  0.262795  0.250292  0.376635  1.000000  0.247114
# Meera     0.191219  0.148113  0.005760  0.179494  0.247114  1.000000
# SNL       0.153886  0.308425  0.026123  0.195784  0.233945  0.043237
# Amaze     0.143142  0.017428  0.208746  0.031351  0.032460 -0.067790
# Caplin    0.070682  0.389955  0.146676  0.160091  0.251901  0.039332
# Balmer    0.218402  0.217243  0.241765  0.472343  0.397802  0.076612
#
#                SNL     Amaze    Caplin    Balmer
# Allsec    0.153886  0.143142  0.070682  0.218402
# Bhansali  0.308425  0.017428  0.389955  0.217243
# Eclerx    0.026123  0.208746  0.146676  0.241765
# ...

# %%
#logarithmic returns
log_ret=np.log(stocks/stocks.shift(1))
log_ret.head()
log_ret.hist(bins=100,figsize=(12,8))
plt.tight_layout()

# %%
stocks.pct_change(1).head()
# Out:
#               Allsec  Bhansali    Eclerx    Sharda   Maithan     Meera  \
# Date
# 2019-08-14       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-08-16  0.038817  0.026863       NaN       NaN -0.010835       NaN
# 2019-08-19 -0.035587 -0.009283  0.016365  0.021184  0.017295  0.000000
# 2019-08-20  0.011070 -0.016184  0.001400 -0.050183 -0.021648 -0.023684
# 2019-08-21 -0.031387 -0.045887 -0.030221  0.001017 -0.011006  0.000000
#
#                SNL  Amaze    Caplin    Balmer
# Date
# 2019-08-14     NaN    NaN       NaN       NaN
# 2019-08-16     NaN    NaN       NaN       NaN
# 2019-08-19  0.0000    0.0 -0.033087  0.009422
# 2019-08-20  0.0000    0.0 -0.022039 -0.002189
# 2019-08-21 -0.0275    0.0 -0.041395 -0.005428

# %%
log_ret.mean()
# Out:
# Allsec      0.000236
# Bhansali   -0.000838
# Eclerx      0.001243
# Sharda     -0.000256
# Maithan     0.000529
# Meera      -0.002874
# SNL        -0.002539
# Amaze       0.001637
# Caplin      0.000769
# Balmer      0.000391
# dtype: float64

# %%
log_ret.cov()
# Out:
#             Allsec  Bhansali    Eclerx    Sharda   Maithan     Meera  \
# Allsec    0.001263  0.000333  0.000328  0.000374  0.000331  0.000322
# Bhansali  0.000333  0.001777  0.000277  0.000387  0.000418  0.000268
# Eclerx    0.000328  0.000277  0.001437  0.000387  0.000363  0.000019
# Sharda    0.000374  0.000387  0.000387  0.001859  0.000593  0.000351
# Maithan   0.000331  0.000418  0.000363  0.000593  0.001257  0.000409
# Meera     0.000322  0.000268  0.000019  0.000351  0.000409  0.001912
# SNL       0.000276  0.000627  0.000054  0.000434  0.000398  0.000087
# Amaze     0.000092  0.000016  0.000158  0.000026  0.000025 -0.000059
# Caplin    0.000148  0.000713  0.000234  0.000333  0.000404  0.000098
# Balmer    0.000174  0.000202  0.000198  0.000438  0.000302  0.000087
#
#                SNL         Amaze    Caplin        Balmer
# Allsec    0.000276  9.197970e-05  0.000148  1.736722e-04
# Bhansali  0.000627  1.550138e-05  0.000713  2.023602e-04
# ...

# %%
log_ret.corr()
# Out:
#             Allsec  Bhansali    Eclerx    Sharda   Maithan     Meera  \
# Allsec    1.000000  0.222075  0.243502  0.244152  0.262526  0.206773
# Bhansali  0.222075  1.000000  0.172858  0.212881  0.279503  0.145135
# Eclerx    0.243502  0.172858  1.000000  0.236679  0.269655  0.011826
# Sharda    0.244152  0.212881  0.236679  1.000000  0.387178  0.186785
# Maithan   0.262526  0.279503  0.269655  0.387178  1.000000  0.262814
# Meera     0.206773  0.145135  0.011826  0.186785  0.262814  1.000000
# SNL       0.167179  0.319995  0.030668  0.216954  0.241195  0.042597
# Amaze     0.126415  0.017935  0.203263  0.029853  0.034724 -0.066531
# Caplin    0.098789  0.401039  0.146867  0.183577  0.270134  0.053013
# Balmer    0.236339  0.231816  0.252398  0.491259  0.411217  0.096163
#
#                SNL     Amaze    Caplin    Balmer
# Allsec    0.167179  0.126415  0.098789  0.236339
# Bhansali  0.319995  0.017935  0.401039  0.231816
# Eclerx    0.030668  0.203263  0.146867  0.252398
# ...

# %%
#annualized covariance
log_ret.cov()*252
# Out:
#             Allsec  Bhansali    Eclerx    Sharda   Maithan     Meera  \
# Allsec    0.318262  0.083835  0.082633  0.094240  0.083355  0.081050
# Bhansali  0.083835  0.447790  0.069683  0.097611  0.105266  0.067605
# Eclerx    0.082633  0.069683  0.362044  0.097465  0.091486  0.004899
# Sharda    0.094240  0.097611  0.097465  0.468393  0.149411  0.088546
# Maithan   0.083355  0.105266  0.091486  0.149411  0.316759  0.102997
# Meera     0.081050  0.067605  0.004899  0.088546  0.102997  0.481824
# SNL       0.069483  0.157990  0.013599  0.109422  0.100223  0.021834
# Amaze     0.023179  0.003906  0.039762  0.006642  0.006365 -0.014881
# Caplin    0.037247  0.179621  0.059078  0.083992  0.101827  0.024642
# Balmer    0.043765  0.050995  0.049865  0.110393  0.076132  0.021958
#
#                SNL     Amaze    Caplin    Balmer
# Allsec    0.069483  0.023179  0.037247  0.043765
# Bhansali  0.157990  0.003906  0.179621  0.050995
# Eclerx    0.013599  0.039762  0.059078  0.049865
# ...

# %%
#creating efficiency frontier
np.random.seed(101)
print(stocks.columns)
weights=np.array(np.random.random(10))
print("Random Weights:")
print(weights)
print('Rebalance')
weights=weights/np.sum(weights)
print(weights)
# Out:
# Index(['Allsec', 'Bhansali', 'Eclerx', 'Sharda', 'Maithan', 'Meera', 'SNL',
#        'Amaze', 'Caplin', 'Balmer'],
#       dtype='object')
# Random Weights:
# [0.51639863 0.57066759 0.02847423 0.17152166 0.68527698 0.83389686
#  0.30696622 0.89361308 0.72154386 0.18993895]
# Rebalance
# [0.10499539 0.11602948 0.00578945 0.03487419 0.13933214 0.16954988
#  0.0624131  0.18169153 0.14670601 0.03861884]

# %%
print('Expected Portfolio Return')
exp_ret=np.sum((log_ret.mean()*weights)*252)
print(exp_ret)
# Out:
# Expected Portfolio Return
# -0.05565230994612429

# %%
#expected volatility calculation
print('Expected Volatility')
exp_vol=np.sqrt(np.dot(weights.T,np.dot(log_ret.cov()*252,weights)))
print(exp_vol)
# Out:
# Expected Volatility
# 0.3066474377541549

# %%
print('Sharpe Ratio')
SR=exp_ret/exp_vol
print(SR)
# Out:
# Sharpe Ratio
# -0.18148630346861666

# %%
np.random.seed(101)
num_ports=5000
all_weights=np.zeros((num_ports,len(stocks.columns)))
ret_arr=np.zeros(num_ports)
vol_arr=np.zeros(num_ports)
sharpe_arr=np.zeros(num_ports)
for ind in range(num_ports):
    weights=np.array(np.random.random(10))
    weights=weights/np.sum(weights)
    all_weights[ind,:]=weights
    ret_arr[ind]=np.sum((log_ret.mean()*weights)*252)
    vol_arr[ind]=np.sqrt(np.dot(weights.T,np.dot(log_ret.cov()*252,weights)))
    sharpe_arr[ind]=ret_arr[ind]/vol_arr[ind]

# %%
sharpe_arr.max()
# Out:
# 0.7797717301570618

# %%
sharpe_arr.argmax()
# Out:
# 1033

# %%
all_weights[1033,:]
# Out:
# array([0.04200021, 0.03172396, 0.26393197, 0.0571005 , 0.11998407,
#        0.01299202, 0.01020263, 0.31370627, 0.11603513, 0.03232323])

# %%
max_sr_ret=ret_arr[1033]
max_sr_vol=vol_arr[1033]
plt.figure(figsize=(12,8))
plt.scatter(vol_arr,ret_arr,c=sharpe_arr,cmap='plasma')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')
plt.scatter(max_sr_vol,max_sr_ret,c='green',s=50,edgecolors='black')

# %% [markdown]
# plt.scatter(max_sr_vol,max_sr_ret,c='red',s=50,edgecolors='black')
